# %%
#Ridge Regresyon: L2 Regularisation ==> katsayı küçültme

# %%
#Lasso:  L1 Regularisation ==> bazı değerleri yok etme

# %%
#ElasticNet: Ridge ve lasso birlikte kullanımı

# %%
#Cross Validation yöntemlerini atılın notlardan bak
