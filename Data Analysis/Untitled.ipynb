# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
age_list = [10,20,30,30,40,50,60,60]

# %%
weight_list = [20,60,80,70,90,95,70,60]

# %%
# plt.subplot(1,2,1)
# plt.plot(age_list,weight_list,"r*-")
# plt.subplot(1,2,2)
# plt.plot(weight_list,age_list,"b--")
# plt.show()

# %%
my_figure = plt.figure()
figure_axes = my_figure.add_axes([0.1,0.1,0.3,0.3,])
figure_axes.plot(weight_list, age_list,"g")
figure_axes.set_xlabel("X axis")
figure_axes.set_ylabel("Y axis")
plt.show()
